# %% [markdown]
# # K-Means - Student Data Set

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/student_data.xlsx')

# %%
df
# Out:
#       ID           Name  Weight (kg)  Height (cm)
# 0      1     Drew Jones           81          167
# 1      2    Reese Brown           85          203
# 2      3    Drew Taylor          102          208
# 3      4  Taylor Miller           82          206
# 4      5    Reese Brown           96          183
# ..   ...            ...          ...          ...
# 195  196    River Brown           60          199
# 196  197    Alex Taylor           63          177
# 197  198   Skyler Smith           54          191
# 198  199    Jamie Davis           59          189
# 199  200   River Wilson           60          198
#
# [200 rows x 4 columns]

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='ID', y='Weight (kg)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
column_names = df.columns.tolist()
column_names
# Out:
# ['ID', 'Name', 'Weight (kg)', 'Height (cm)']

# %%
df.plot(kind = 'scatter',x = 'Weight (kg)', y='Height (cm)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Weight vs Height')
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
# Out:
# Text(0, 0.5, 'Height (cm)')

# %% [markdown]
# ## K-Means clustering (Number of clusters(n) = 2)

# %%
import sklearn
kmeans = sklearn.cluster.KMeans(n_clusters = 2, random_state = 12)
X = df[['Weight (kg)','Height (cm)']]
print(X)
# Out:
#      Weight (kg)  Height (cm)
# 0             81          167
# 1             85          203
# 2            102          208
# 3             82          206
# 4             96          183
# ..           ...          ...
# 195           60          199
# 196           63          177
# 197           54          191
# 198           59          189
# 199           60          198
#
# [200 rows x 2 columns]

# %%
kmeans.fit(X)
df['Clusters'] = kmeans.predict(X)
centers = kmeans.cluster_centers_
print(centre)
# Out:
# [[ 83.09183673 178.40816327]
#  [ 51.85294118 172.04901961]]

# %%
print(df)
# Out:
#       ID           Name  Weight (kg)  Height (cm)  Clusters
# 0      1     Drew Jones           81          167         0
# 1      2    Reese Brown           85          203         0
# 2      3    Drew Taylor          102          208         0
# 3      4  Taylor Miller           82          206         0
# 4      5    Reese Brown           96          183         0
# ..   ...            ...          ...          ...       ...
# 195  196    River Brown           60          199         1
# 196  197    Alex Taylor           63          177         1
# 197  198   Skyler Smith           54          191         1
# 198  199    Jamie Davis           59          189         1
# 199  200   River Wilson           60          198         1
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize=(10,10))
plt.scatter(X["Weight (kg)"], X["Height (cm)"], c=df['Clusters'], cmap='rainbow', alpha=0.6, s=100, label='Data Points')
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='X', s=200, label='Cluster Centers')
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
plt.title('K-Means Clustering of Students')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## K - Means (number of cluster (N = 3)

# %%
kmeans = sklearn.cluster.KMeans(n_clusters = 3 , random_state = 12)
kmeans.fit(X)
centers = kmeans.cluster_centers_
df['Clusters'] = kmeans.predict(X)
print(centers)
# Out:
# [[ 85.16393443 167.85245902]
#  [ 50.06578947 165.23684211]
#  [ 70.34920635 194.22222222]]

# %%
df
# Out:
#       ID           Name  Weight (kg)  Height (cm)  Clusters
# 0      1     Drew Jones           81          167         0
# 1      2    Reese Brown           85          203         2
# 2      3    Drew Taylor          102          208         2
# 3      4  Taylor Miller           82          206         2
# 4      5    Reese Brown           96          183         0
# ..   ...            ...          ...          ...       ...
# 195  196    River Brown           60          199         2
# 196  197    Alex Taylor           63          177         1
# 197  198   Skyler Smith           54          191         2
# 198  199    Jamie Davis           59          189         2
# 199  200   River Wilson           60          198         2
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize=(10,10))
plt.scatter(X["Weight (kg)"], X["Height (cm)"], c=df['Clusters'], cmap='rainbow', alpha=0.6, s=100, label='Data Points')
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='X', s=200, label='Cluster Centers')
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
plt.title('K-Means Clustering of Students')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## K-Means Clustering (n = 4)

# %%
kmeans = sklearn.cluster.KMeans(n_clusters = 4 , random_state = 12)
kmeans.fit(X)
centers = kmeans.cluster_centers_
df['Clusters'] = kmeans.predict(X)
print(centers)
# Out:
# [[ 84.52941176 194.35294118]
#  [ 49.62295082 161.73770492]
#  [ 56.72916667 188.72916667]
#  [ 84.35087719 166.66666667]]

# %%
df
# Out:
#       ID           Name  Weight (kg)  Height (cm)  Clusters
# 0      1     Drew Jones           81          167         3
# 1      2    Reese Brown           85          203         0
# 2      3    Drew Taylor          102          208         0
# 3      4  Taylor Miller           82          206         0
# 4      5    Reese Brown           96          183         0
# ..   ...            ...          ...          ...       ...
# 195  196    River Brown           60          199         2
# 196  197    Alex Taylor           63          177         2
# 197  198   Skyler Smith           54          191         2
# 198  199    Jamie Davis           59          189         2
# 199  200   River Wilson           60          198         2
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize=(10,10))
plt.scatter(X["Weight (kg)"], X["Height (cm)"], c=df['Clusters'], cmap='rainbow', alpha=0.6, s=100, label='Data Points')
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='X', s=200, label='Cluster Centers')
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
plt.title('K-Means Clustering of Students')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Using Elbow method
#
# To calculate required number of clusters

# %%
inertia= []
for i in range(1,11):
  kmeans = sklearn.cluster.KMeans(n_clusters = i, random_state = 20)
  kmeans.fit(X)
  inertia.append(kmeans.inertia_)
plt.figure(figsize =(5,5))
plt.plot(range(1,11), inertia, marker = 'o', linestyle = '--')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# # K-Means on World Bank dataset

# %% [markdown]
# ### Installing World Data API library

# %%
# !pip3 install -U wbdata

# %% [markdown]
# ### Extracting countries and indicator IDs for required data fetching

# %%
import wbdata
import pandas as pd

sources = wbdata.get_sources()
countries = pd.DataFrame(wbdata.get_countries())
indicators = pd.DataFrame(wbdata.get_indicators())
with pd.ExcelWriter("world_bank_data.xlsx", engine='openpyxl') as writer:
    countries.to_excel(writer, sheet_name="Countries", index=False)
    indicators.to_excel(writer, sheet_name="Indicators", index=False)

print("Data saved to world_bank_data.xlsx")
# Out:
# Data saved to world_bank_data.xlsx

# %% [markdown]
# ### Defining Indicators, specifying time (1st January 2016 - 31st Decemeber 2020)
# ### Downloading dataset

# %%
import datetime
start_date = datetime.datetime(2016, 1, 1)
end_date = datetime.datetime(2020, 12, 31)

# Define the indicators
indicators = {
    'NY.GDP.PCAP.CD': 'GDP per Capita',
    'SI.POV.GINI': 'Gini Coefficient',
    'SI.POV.DDAY': 'Poverty Headcount Ratio at $1.90/day',
    'SL.UEM.TOTL.ZS': 'Unemployment Rate',
    'GC.DOD.TOTL.GD.ZS': 'Debt-to-GDP Ratio'
}

# Define the countries of interest (ISO 3-letter codes)
countries = ['USA', 'CHN', 'DEU', 'JPN', 'IND', 'BRA', 'RUS', 'GBR', 'CAN', 'FRA']

# Fetch the data for the last 5 years
data = wbdata.get_dataframe(indicators, country=countries, date=(start_date, end_date))

# Reset index to make 'country' and 'date' as columns
data.reset_index(inplace=True)
print(data.head(n = len(data)))
# Out:
#                country  date  GDP per Capita  Gini Coefficient  \
# 0               Brazil  2020     7074.193783              48.9
# 1               Brazil  2019     9029.833267              53.5
# 2               Brazil  2018     9300.661649              53.9
# 3               Brazil  2017    10080.509282              53.3
# 4               Brazil  2016     8836.286526              53.4
# 5               Canada  2020    43537.839299               NaN
# 6               Canada  2019    46352.869345              31.7
# 7               Canada  2018    46539.176157              32.5
# 8               Canada  2017    45129.628117              33.3
# 9               Canada  2016    42314.061582              32.7
# 10               China  2020    10408.719554              37.1
# 11               China  2019    10143.860221              38.2
# 12               China  2018     9905.406383              38.5
# 13               China  2017     8817.045608              39.1
# ...

# %%
data.shape
data.isnull().sum()
# Out:
# country                                  0
# date                                     0
# GDP per Capita                           0
# Gini Coefficient                         6
# Poverty Headcount Ratio at $1.90/day     6
# Unemployment Rate                        0
# Debt-to-GDP Ratio                       12
# dtype: int64

# %%
# Drop rows with missing values
data_clean = data.dropna()
data_clean.shape
# Out:
# (32, 7)

# %% [markdown]
# ### Data scaling

# %%
from sklearn.preprocessing import StandardScaler

features = ['GDP per Capita', 'Gini Coefficient', 'Poverty Headcount Ratio at $1.90/day', 'Unemployment Rate', 'Debt-to-GDP Ratio']

scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_clean[features])

print(pd.DataFrame(data_scaled, columns=features).head())
# Out:
#    GDP per Capita  Gini Coefficient  Poverty Headcount Ratio at $1.90/day  \
# 0       -1.161958          1.576917                             -0.071335
# 1       -1.067776          2.217962                              0.728796
# 2       -1.054733          2.273705                              0.705263
# 3       -1.017176          2.190090                              0.705263
# 4       -1.077097          2.204026                              0.564063
#
#    Unemployment Rate  Debt-to-GDP Ratio
# 0           2.283153           0.260451
# 1           1.673386           0.129768
# 2           1.809467           0.003068
# 3           1.969786          -0.059432
# 4           1.550117          -0.277436

# %% [markdown]
# ### Using Elbow Method to determine K cluster

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Elbow Method to find optimal number of clusters
inertia = []  # Within-cluster sum of squares
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(data_scaled)
    inertia.append(kmeans.inertia_)

# Plotting the Elbow Method graph
plt.plot(range(1, 11), inertia,marker = 'o', linestyle = '--')
plt.title('Elbow Method for Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS (Within-cluster Sum of Squares)')
plt.show()

# %% [markdown]
# ### Wihtout using PCA

# %%
kmeans = KMeans(n_clusters= 5, init='k-means++', max_iter=300, n_init=10, random_state=42)
clusters = kmeans.fit_predict(data_scaled)

# Add the cluster labels to the original data
data_clean['Cluster'] = clusters

# Display the data with cluster labels
#print(data_clean.head())
# Out:
# <ipython-input-70-b5cfd408ea9b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['Cluster'] = clusters

# %%
# Grouping the data by clusters and calculating the mean values of each feature
cluster_means = data_clean.select_dtypes(include='number').groupby(data_clean['Cluster']).mean()

# Display the means for each cluster
#print(cluster_means)

# %%
countries_by_cluster =pd.DataFrame(data_clean.groupby('Cluster')['country'].apply(list))
countries_by_cluster
# Out:
#                                                    country
# Cluster
# 0        [Canada, Canada, Canada, Canada, France, Franc...
# 1        [Russian Federation, Russian Federation, Russi...
# 2                 [Brazil, Brazil, Brazil, Brazil, Brazil]
# 3                                    [India, India, India]
# 4        [United Kingdom, United Kingdom, United Kingdo...

# %% [markdown]
# With PCA(n = 2)

# %%
data_scaled
pca = PCA(n_components=2)
pca_components = pca.fit_transform(data_scaled)
pca_df = pd.DataFrame(data=pca_components, columns=['PC1', 'PC2'])

# %%
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state = 42)
    kmeans.fit(data_scaled)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 11), inertia,marker = 'o', linestyle = '--')
plt.title('Elbow Method for Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS (Within-cluster Sum of Squares)')
# Out:
# Text(0, 0.5, 'WCSS (Within-cluster Sum of Squares)')

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=42)
clusters = kmeans.fit_predict(data_scaled)
country_clusters = pd.DataFrame({'Country': data_clean['country'], 'Cluster': clusters})
country_clusters
# Out:
#                Country  Cluster
# 0               Brazil        2
# 1               Brazil        2
# 2               Brazil        2
# 3               Brazil        2
# 4               Brazil        2
# 6               Canada        0
# 7               Canada        0
# 8               Canada        0
# 9               Canada        0
# 20              France        0
# 21              France        0
# 22              France        0
# 23              France        0
# 24              France        0
# 25      United Kingdom        4
# 26      United Kingdom        4
# 27      United Kingdom        4
# 28      United Kingdom        4
# 29      United Kingdom        4
# 32               India        3
# 33               India        3
# 34               India        3
# 40  Russian Federation        1
# 41  Russian Federation        1
# 42  Russian Federation        1
# 43  Russian Federation        1
# 44  Russian Federation        1
# 45       United States        4
# ...

# %%
from sklearn.decomposition import PCA

# Perform PCA to reduce the data to 2D
pca = PCA(n_components=2)
pca_components = pca.fit_transform(data_scaled)

# Create a DataFrame with PCA components and cluster labels
pca_df = pd.DataFrame(data=pca_components, columns=['PC1', 'PC2'])
pca_df['Cluster'] = clusters

# Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], c=pca_df['Cluster'], cmap='viridis', label='Cluster')
plt.title('Clusters Visualization (PCA)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
